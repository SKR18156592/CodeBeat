# %%
# %load_ext autoreload
# %autoreload

# %%
from codebeat import code_tracker

# code_tracker)

# %%
def fun1(x, y):
    m = 0
    for i in range(x):
        for j in range(y):
            m += i*j 
    return m

# %%
obj = code_tracker(fun1) # modify, create executable

obj(3, 4) # for loop for n times and call fun and display final result
# Out:
# ======================================================================================================================================================================================
# |> Function Name: fun, #iter:10, mean_time(in ms):0.008, std_time(in ms):0.003
# ======================================================================================================================================================================================
# | line No | Line                      | mean_time(in ms)       | std_time(in ms)
# ======================================================================================================================================================================================
# | 0       |    m = 0                  | 0.000                  | 0.000
# | 1       |    for i in range(x):     | 0.004                  | 0.002
# | 2       |        for j in range(y): | 0.002                  | 0.001
# | 3       |            m += i*j       | 0.001                  | 0.000
# | 4       |    return m               | nan                    | nan
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
